# %% [markdown]
# #Crime Rate Against Women
# >>Data from 'Data.gov.in'
#
# File names:
#     >>crcCAW.CSV : `Number of Crime against women`
#     >>pacCAW.CSV : 'Number of Person Involved in Crime against Women'

# %%
# Import Necessary Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
% matplotlib inline

# %%
crimes = pd.read_csv('crcCAW.csv')

# %%
crimes.head()
# Out:
#             STATE/UT CRIME HEAD  2001  2002  2003  2004  2005  2006  2007  \
# 0     ANDHRA PRADESH       RAPE   871  1002   946  1016   935  1049  1070
# 1  ARUNACHAL PRADESH       RAPE    33    38    31    42    35    37    48
# 2              ASSAM       RAPE   817   970  1095  1171  1238  1244  1437
# 3              BIHAR       RAPE   888  1040   985  1390  1147  1232  1555
# 4       CHHATTISGARH       RAPE   959   992   898   969   990   995   982
#
#    2008  2009  2010  2011  2012
# 0  1257  1188  1362  1442  1341
# 1    42    59    47    42    46
# 2  1438  1631  1721  1700  1716
# 3  1302   929   795   934   927
# 4   978   976  1012  1053  1034

# %%
crimes.plot()

# %% [markdown]
# The above Plot is not Satisfactory and is not accurate so lets look at data once again

# %%
crimes.head()
# Out:
#             STATE/UT CRIME HEAD  2001  2002  2003  2004  2005  2006  2007  \
# 0     ANDHRA PRADESH       RAPE   871  1002   946  1016   935  1049  1070
# 1  ARUNACHAL PRADESH       RAPE    33    38    31    42    35    37    48
# 2              ASSAM       RAPE   817   970  1095  1171  1238  1244  1437
# 3              BIHAR       RAPE   888  1040   985  1390  1147  1232  1555
# 4       CHHATTISGARH       RAPE   959   992   898   969   990   995   982
#
#    2008  2009  2010  2011  2012
# 0  1257  1188  1362  1442  1341
# 1    42    59    47    42    46
# 2  1438  1631  1721  1700  1716
# 3  1302   929   795   934   927
# 4   978   976  1012  1053  1034

# %% [markdown]
#     Lets try Something different :
#     first extract Rape data in new dataframe
#     Note: Rape data in first 29 rows

# %%
crimes.values
# Out:
# array([['ANDHRA PRADESH', 'RAPE', 871L, ..., 1362L, 1442L, 1341L],
#        ['ARUNACHAL PRADESH', 'RAPE', 33L, ..., 47L, 42L, 46L],
#        ['ASSAM', 'RAPE', 817L, ..., 1721L, 1700L, 1716L],
#        ...,
#        ['PUDUCHERRY', 'TOTAL CRIMES AGAINST WOMEN', 119L, ..., 115L, 89L,
#         61L],
#        ['TOTAL (UTs)', 'TOTAL CRIMES AGAINST WOMEN', 2623L, ..., 4904L,
#         5559L, 6339L],
#        ['TOTAL (ALL-INDIA)', 'TOTAL CRIMES AGAINST WOMEN', 143795L, ...,
#         213585L, 228650L, 244270L]], dtype=object)

# %% [markdown]
#    ** Lets try to sum up the all the crimes **

# %%
year_wise_crime = crimes.ix[:,2:].sum(axes=1)

# %%
year_wise_crime
# Out:
# 2001     862770
# 2002     858204
# 2003     843606
# 2004     925998
# 2005     933318
# 2006     988590
# 2007    1111872
# 2008    1175142
# 2009    1222824
# 2010    1281510
# 2011    1371900
# 2012    1465620
# dtype: int64

# %%
year_wise_crime.plot(kind='bar', figsize=(8,5), legend=True, title='Number of Crimes per Year',)

# %% [markdown]
# ** Yet another plot using Line **

# %%
year_wise_crime.plot(kind='line')

# %% [markdown]
# `Making it more Beautful`

# %%
year_wise_crime.columns = ['Crimes']
year_wise_crime
year_wise_crime.index.values
# Out:
# array(['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012'], dtype=object)

# %%
year_wise_crime.plot(figsize=(10,5))

# %%
year_wise_crime.plot(kind='bar')

# %%
year_wise_crime.plot(kind='barh', figsize=(10,5))

# %% [markdown]
#  ** Now the Problem with above data is we have also summed up the total values did you  notice the Total row name in Dataframe **

# %% [markdown]
# **Now we will try to get only rape data**

# %%
crimes.head()
# Out:
#             STATE/UT CRIME HEAD  2001  2002  2003  2004  2005  2006  2007  \
# 0     ANDHRA PRADESH       RAPE   871  1002   946  1016   935  1049  1070
# 1  ARUNACHAL PRADESH       RAPE    33    38    31    42    35    37    48
# 2              ASSAM       RAPE   817   970  1095  1171  1238  1244  1437
# 3              BIHAR       RAPE   888  1040   985  1390  1147  1232  1555
# 4       CHHATTISGARH       RAPE   959   992   898   969   990   995   982
#
#    2008  2009  2010  2011  2012
# 0  1257  1188  1362  1442  1341
# 1    42    59    47    42    46
# 2  1438  1631  1721  1700  1716
# 3  1302   929   795   934   927
# 4   978   976  1012  1053  1034

# %%
rape = crimes[crimes['CRIME HEAD'] == 'RAPE']
rape
# Out:
#              STATE/UT CRIME HEAD   2001   2002   2003   2004   2005   2006  \
# 0      ANDHRA PRADESH       RAPE    871   1002    946   1016    935   1049
# 1   ARUNACHAL PRADESH       RAPE     33     38     31     42     35     37
# 2               ASSAM       RAPE    817    970   1095   1171   1238   1244
# 3               BIHAR       RAPE    888   1040    985   1390   1147   1232
# 4        CHHATTISGARH       RAPE    959    992    898    969    990    995
# 5                 GOA       RAPE     12     12     31     37     20     21
# 6             GUJARAT       RAPE    286    267    236    339    324    354
# 7             HARYANA       RAPE    398    361    353    386    461    608
# 8    HIMACHAL PRADESH       RAPE    124    137    126    153    141    113
# 9     JAMMU & KASHMIR       RAPE    169    192    211    218    201    250
# 10          JHARKHAND       RAPE    567    797    712    797    753    799
# 11          KARNATAKA       RAPE    293    292    321    291    343    400
# 12             KERALA       RAPE    562    499    394    480    478    601
# 13     MADHYA PRADESH       RAPE   2851   2891   2738   2875   2921   2900
# 14        MAHARASHTRA       RAPE   1302   1352   1268   1388   1545   1500
# 15            MANIPUR       RAPE     20     14     18     31     25     40
# 16          MEGHALAYA       RAPE     26     38     40     54     63     74
# 17            MIZORAM       RAPE     52     76     54     20     37     72
# 18           NAGALAND       RAPE     17     17     14     18     17     23
# 19             ODISHA       RAPE    790    691    725    770    799    985
# 20             PUNJAB       RAPE    298    299    380    390    398    442
# 21          RAJASTHAN       RAPE   1049   1051   1050   1038    993   1085
# 22             SIKKIM       RAPE      8      6     10      3     18     20
# 23         TAMIL NADU       RAPE    423    534    557    618    571    457
# 24            TRIPURA       RAPE    102    108    114    160    162    189
# 25      UTTAR PRADESH       RAPE   1958   1415    911   1397   1217   1314
# 26        UTTARAKHAND       RAPE     74     89    107    115    133    147
# 27        WEST BENGAL       RAPE    709    759   1002   1475   1686   1731
# 28     TOTAL (STATES)       RAPE  15658  15939  15327  17641  17651  18682
# 29      A & N ISLANDS       RAPE      3      2      2     10      4      6
# 30         CHANDIGARH       RAPE     18     18     18     19     33     19
# 31       D & N HAVELI       RAPE      6      4      1      7      5      6
# 32        DAMAN & DIU       RAPE      0      0      5      1      2      3
# 33              DELHI       RAPE    381    403    490    551    658    623
# 34        LAKSHADWEEP       RAPE      0      1      2      0      0      0
# 35         PUDUCHERRY       RAPE      9      6      2      4      6      9
# 36        TOTAL (UTs)       RAPE    417    434    520    592    708    666
# 37  TOTAL (ALL-INDIA)       RAPE  16075  16373  15847  18233  18359  19348
#
#      2007   2008   2009   2010   2011   2012
# 0    1070   1257   1188   1362   1442   1341
# 1      48     42     59     47     42     46
# 2    1437   1438   1631   1721   1700   1716
# 3    1555   1302    929    795    934    927
# 4     982    978    976   1012   1053   1034
# 5      20     30     47     36     29     55
# 6     316    374    433    408    439    473
# 7     488    631    603    720    733    668
# 8     159    157    183    160    168    183
# 9     288    219    237    245    277    303
# 10    855    791    719    773    784    812
# 11    436    446    509    586    636    621
# 12    512    568    568    634   1132   1019
# 13   3010   2937   2998   3135   3406   3425
# 14   1451   1558   1483   1599   1701   1839
# 15     20     38     31     34     53     63
# 16     82     88    112    149    130    164
# 17     83     77     83     92     77    103
# 18     13     19     22     16     23     21
# 19    939   1113   1023   1025   1112   1458
# 20    519    517    511    546    479    680
# 21   1238   1355   1519   1571   1800   2049
# 22     24     20     18     18     16     34
# 23    523    573    596    686    677    737
# 24    157    204    190    238    205    229
# 25   1648   1871   1759   1563   2042   1963
# 26    117     87    111    121    129    148
# 27   2106   2263   2336   2311   2363   2046
# 28  20096  20953  20874  21603  23582  24157
# 29      3     12     18     24     13     12
# 30     22     20     29     31     27     27
# 31      7      6      4      3      4      3
# 32      1      0      1      1      1      5
# 33    598    466    469    507    572    706
# 34      1      2      1      0      0      0
# 35      9      8      1      3      7     13
# 36    641    514    523    569    624    766
# 37  20737  21467  21397  22172  24206  24923

# %%
totalrape = rape[rape['STATE/UT'] == 'TOTAL (ALL-INDIA)']
totalrape
# Out:
#              STATE/UT CRIME HEAD   2001   2002   2003   2004   2005   2006  \
# 37  TOTAL (ALL-INDIA)       RAPE  16075  16373  15847  18233  18359  19348
#
#      2007   2008   2009   2010   2011   2012
# 37  20737  21467  21397  22172  24206  24923

# %%
#df1.iloc[1:5,2:4]
totalrape2 = totalrape.iloc[:,2:].T

# %%
totalrape2
totalrape2.index.name = 'Year'
totalrape2.columns = ['No. of Crimes']
totalrape2
# Out:
#       No. of Crimes
# Year
# 2001          16075
# 2002          16373
# 2003          15847
# 2004          18233
# 2005          18359
# 2006          19348
# 2007          20737
# 2008          21467
# 2009          21397
# 2010          22172
# 2011          24206
# 2012          24923

# %%
totalrape2.plot(figsize=(8,5), title='Number of Rapes per Year\n in India')

# %% [markdown]
# The above is the final Diagram on rape in india

# %%
totalcrimes = crimes[crimes['CRIME HEAD'] == 'TOTAL CRIMES AGAINST WOMEN']
totalcrimes.head()
# Out:
#               STATE/UT                  CRIME HEAD   2001   2002   2003  \
# 418     ANDHRA PRADESH  TOTAL CRIMES AGAINST WOMEN  16477  18880  18382
# 419  ARUNACHAL PRADESH  TOTAL CRIMES AGAINST WOMEN    180    159    139
# 420              ASSAM  TOTAL CRIMES AGAINST WOMEN   4243   5092   5312
# 421              BIHAR  TOTAL CRIMES AGAINST WOMEN   5356   5743   5900
# 422       CHHATTISGARH  TOTAL CRIMES AGAINST WOMEN   3989   3538   3336
#
#       2004   2005   2006   2007   2008   2009   2010   2011   2012
# 418  18921  20819  21484  24738  24111  25569  27244  28246  28171
# 419    148    150    168    185    175    164    190    171    201
# 420   5700   6027   6801   6844   8122   9721  11555  11503  13544
# 421   8091   6019   6740   7548   8662   8803   8471  10231  11229
# 422   3763   3599   3757   3775   3962   4002   4176   4219   4228

# %%
totalcrimes1 = totalcrimes[totalcrimes['STATE/UT'] == 'TOTAL (ALL-INDIA)']

# %%
totalcrimes1
# Out:
#               STATE/UT                  CRIME HEAD    2001    2002    2003  \
# 455  TOTAL (ALL-INDIA)  TOTAL CRIMES AGAINST WOMEN  143795  143034  140601
#
#        2004    2005    2006    2007    2008    2009    2010    2011    2012
# 455  154333  155553  164765  185312  195857  203804  213585  228650  244270

# %%
finaltotalcrimes = totalcrimes1.iloc[:,2:]
finaltotalcrimes
# Out:
#        2001    2002    2003    2004    2005    2006    2007    2008    2009  \
# 455  143795  143034  140601  154333  155553  164765  185312  195857  203804
#
#        2010    2011    2012
# 455  213585  228650  244270

# %%
finaltotalcrimes = finaltotalcrimes.T

# %%
finaltotalcrimes.index.name = 'Year'
finaltotalcrimes.columns = ['TOTAL CRIMES AGAINST WOMEN']
finaltotalcrimes
# Out:
#       TOTAL CRIMES AGAINST WOMEN
# Year
# 2001                      143795
# 2002                      143034
# 2003                      140601
# 2004                      154333
# 2005                      155553
# 2006                      164765
# 2007                      185312
# 2008                      195857
# 2009                      203804
# 2010                      213585
# 2011                      228650
# 2012                      244270

# %%
plt  = finaltotalcrimes.plot(figsize=(7,5), title='Total Crimes Against Women per Year\n In India ')

# %%
bar  = finaltotalcrimes.plot(kind = 'bar',figsize=(8,5), title='Total Crimes Against Women per Year\n In India ')

# %%
#to drop rows ::df.drop(df.index[[1,3]])
